# %% [markdown]
# # Aplicação de filtros em imagens

# %% [markdown]
# ## Exemplo 01
#
# ### 1. Instalando a biblioteca Pillow:

# %%
# !pip install pillow

# %% [markdown]
# Iniciando o código

# %%
import PIL

# %% [markdown]
# ## Chamamos nossa classe para manipulação de imagens

# %%
from PIL import Image

# %% [markdown]
# Inserindo nossa imagem

# %%
image = Image.open("sample_data/salgado1.png")

# %% [markdown]
# Classe para visualizarmos nossa imagem:

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=351x351 at 0x7F5B4FD42D50>
